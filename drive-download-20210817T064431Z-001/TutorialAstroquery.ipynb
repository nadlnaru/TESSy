# %%
# !pip install astroquery
# Out:
# ...
#      |████████████████████████████████| 4.4 MB 5.0 MB/s
# ...
#      |████████████████████████████████| 802 kB 40.4 MB/s
# ...
#      |████████████████████████████████| 54 kB 2.4 MB/s
# ...
#      |████████████████████████████████| 3.2 MB 48.7 MB/s
# ...
#   Created wheel for mimeparse: filename=mimeparse-0.1.3-py3-none-any.whl size=3864 sha256=de7581aba68ef894166b5f5551e3a3f84f2b1b7a8eb0ad125091d34a58ba1838
#   Stored in directory: /root/.cache/pip/wheels/49/b4/2d/0081759ae1833bd694024801f7aacddcda8a687e8d5fbaeebd
# Successfully built mimeparse
# ...

# %%
from astroquery.mast import Observations

# %%
obs_table = Observations.query_region("322.49324 12.16683")
(obs_table)
# Out:
# WARNING: InputWarning: Coordinate string is being interpreted as an ICRS coordinate provided in degrees. [astroquery.utils.commons]
# <Table masked=True length=2108>
# intentType obs_collection provenance_name ...  obsid        distance
#    str7        str11           str12      ...   str8        float64
# ---------- -------------- --------------- ... -------- ------------------
#    science          SWIFT              -- ...  1455548                0.0
#    science          SWIFT              -- ...  1455549                0.0
#    science          SWIFT              -- ...  1514187                0.0
#    science          SWIFT              -- ...  1455550                0.0
#    science          SWIFT              -- ...  1515379                0.0
#    science          SWIFT              -- ...  1515380                0.0
#    science          SWIFT              -- ...  1453534                0.0
#    science          SWIFT              -- ...  1478168                0.0
# ...

# %%
obs_table = Observations.query_object("M8")
print(obs_table)
# Out:
# intentType obs_collection provenance_name ... srcDen  obsid        distance
# ---------- -------------- --------------- ... ------ -------- ------------------
#    science          SWIFT              -- ... 5885.0  1384694  635.4612640135151
#    science    SPITZER_SHA    SSC Pipeline ...    nan  1647157                0.0
#    science    SPITZER_SHA    SSC Pipeline ...    nan  1647157                0.0
#    science    SPITZER_SHA    SSC Pipeline ...    nan  1647157                0.0
#    science    SPITZER_SHA    SSC Pipeline ...    nan  1647157                0.0
#    science    SPITZER_SHA    SSC Pipeline ...    nan  1647157                0.0
#    science    SPITZER_SHA    SSC Pipeline ...    nan  1647157                0.0
#    science    SPITZER_SHA    SSC Pipeline ...    nan  1647157                0.0
#    science    SPITZER_SHA    SSC Pipeline ...    nan  1647157                0.0
#    science    SPITZER_SHA    SSC Pipeline ...    nan  1647157                0.0
# ...
